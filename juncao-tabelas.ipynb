# %% [markdown]
# Ler arquivos

# %%
import pandas as pd
import pickle

# importar o arquivo csv
tabela_quimioterapia_2008 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2008.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2009 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2009.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2010 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2010.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2011 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2011.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2012 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2012.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2013 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2013.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2014 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2014.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2015 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2015.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2016 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2016.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2017 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2017.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2018 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2018.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2019 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2019.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2020 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2020.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2021 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2021.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2022 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2022.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2023 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2023.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2024 = pd.read_csv('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/Quimioterapia_rj_2024.csv', encoding='ISO-8859-1', low_memory=False)

#concatenar tabelas em uma única
df = pd.concat([tabela_quimioterapia_2008, tabela_quimioterapia_2009, tabela_quimioterapia_2010, tabela_quimioterapia_2011, tabela_quimioterapia_2012, tabela_quimioterapia_2013, tabela_quimioterapia_2014, tabela_quimioterapia_2015, tabela_quimioterapia_2016, tabela_quimioterapia_2017, tabela_quimioterapia_2018, tabela_quimioterapia_2019, tabela_quimioterapia_2020, tabela_quimioterapia_2021, tabela_quimioterapia_2022, tabela_quimioterapia_2023, tabela_quimioterapia_2024],axis=0, ignore_index=True)

df.to_csv('quimioterapia_2008_2004_discriptografado.csv', index=True)

# %%
dados_serializados = pickle.dumps(df)
with open('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/arquivo.pickle', 'wb') as arquivo:
    arquivo.write(dados_serializados)

# %%
df = pd.read_pickle('C:/Users/Rafaela/Documents/TCC Sistemas de Informação/dataset-SUS/Dados do DATA SUS/Quimioterapia/RJ/arquivo.pickle')
df.describe().transpose()
# Out:
#                 count          mean           std           min           25%  \
# AP_MVM      3721652.0  2.017126e+05  4.762375e+02  2.008010e+05  2.013080e+05
# AP_GESTAO   3721652.0  3.303667e+05  1.857753e+02  3.300000e+05  3.302400e+05
# AP_CODUNI   3721652.0  2.070106e+06  6.791186e+05  1.250500e+04  2.269899e+06
# AP_AUTORIZ  3721652.0  3.317183e+12  4.744536e+09  3.307206e+12  3.313202e+12
# AP_CMP      3721652.0  2.017107e+05  4.760842e+02  2.008010e+05  2.013080e+05
# AP_PRIPAL   3721346.0  3.040361e+08  1.511042e+04  3.040200e+08  3.040201e+08
# AP_VL_AP    3721651.0  5.347525e+02  8.900492e+02  0.000000e+00  7.975000e+01
# AP_UFMUN    3721652.0  3.303973e+05  1.571280e+02  3.300400e+05  3.303900e+05
# AP_TPUPS    3721652.0  6.243046e+00  3.455321e+00  4.000000e+00  5.000000e+00
# AP_TIPPRE   3721652.0  1.555073e+01  2.260594e+01  0.000000e+00  0.000000e+00
# AP_CNPJCPF  3721652.0  2.433959e+13  1.615323e+13  3.945440e+11  3.945440e+11
# ...

# %%
# imprimir os dados da tabela
print(df.info())
df['AP_CNSPCN'].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3721652 entries, 0 to 3721651
# Data columns (total 74 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   AP_MVM      int64
#  1   AP_CONDIC   object
#  2   AP_GESTAO   int64
#  3   AP_CODUNI   int64
#  4   AP_AUTORIZ  int64
#  5   AP_CMP      int64
#  6   AP_PRIPAL   float64
#  7   AP_VL_AP    float64
#  8   AP_UFMUN    int64
#  9   AP_TPUPS    int64
#  10  AP_TIPPRE   int64
#  11  AP_MN_IND   object
#  12  AP_CNPJCPF  int64
#  13  AP_CNPJMNT  float64
#  14  AP_CNSPCN   object
#  15  AP_COIDADE  int64
#  16  AP_NUIDADE  int64
#  17  AP_SEXO     object
#  18  AP_RACACOR  int64
#  19  AP_MUNPCN   int64
#  20  AP_UFNACIO  float64
#  21  AP_CEPPCN   int64
#  22  AP_UFDIF    int64
#  23  AP_MNDIF    int64
#  24  AP_DTINIC   int64
#  25  AP_DTFIM    int64
#  26  AP_TPATEN   int64
#  27  AP_TPAPAC   int64
#  28  AP_MOTSAI   int64
#  29  AP_OBITO    int64
#  30  AP_ENCERR   int64
#  31  AP_PERMAN   int64
# ...

# %%
print(df.describe())
# Out:
#              AP_MVM     AP_GESTAO     AP_CODUNI    AP_AUTORIZ        AP_CMP  \
# count  3.721652e+06  3.721652e+06  3.721652e+06  3.721652e+06  3.721652e+06
# mean   2.017126e+05  3.303667e+05  2.070106e+06  3.317183e+12  2.017107e+05
# std    4.762375e+02  1.857753e+02  6.791186e+05  4.744536e+09  4.760842e+02
# min    2.008010e+05  3.300000e+05  1.250500e+04  3.307206e+12  2.008010e+05
# 25%    2.013080e+05  3.302400e+05  2.269899e+06  3.313202e+12  2.013080e+05
# 50%    2.018030e+05  3.304550e+05  2.273462e+06  3.318201e+12  2.018030e+05
# 75%    2.021090e+05  3.304550e+05  2.280167e+06  3.321205e+12  2.021090e+05
# max    2.024080e+05  3.306300e+05  9.679626e+06  3.324208e+12  2.024080e+05
#
#           AP_PRIPAL      AP_VL_AP      AP_UFMUN      AP_TPUPS     AP_TIPPRE  \
# count  3.721346e+06  3.721651e+06  3.721652e+06  3.721652e+06  3.721652e+06
# mean   3.040361e+08  5.347525e+02  3.303973e+05  6.243046e+00  1.555073e+01
# ...

# %%
#Excluir colunas

df = df.drop(['AP_CONDIC', 'AP_GESTAO', 'AP_CODUNI', 'AP_AUTORIZ', 'AP_VL_AP', 'AP_UFMUN', 'AP_TPUPS', 'AP_TIPPRE', 'AP_MN_IND','AP_CNPJCPF', 'AP_CNPJMNT', 'AP_MUNPCN','AP_UFNACIO', 'AP_CEPPCN','AP_UFDIF', 'AP_MNDIF', 'AP_TPATEN',  'AP_TPAPAC', 'AP_DTOCOR', 'AP_CODEMI', 'AP_APACANT', 'AP_UNISOL', 'AP_ETNIA', 'AP_NATJUR',  'AQ_MED01', 'AQ_MED02', 'AQ_MED03', 'AQ_MED04', 'AQ_MED05', 'AQ_MED06', 'AQ_MED07', 'AQ_MED08', 'AQ_MED09', 'AQ_MED10','AP_DTSOLIC', 'AP_DTAUT', 'AQ_GRAHIS', 'AQ_DTIDEN', 'AP_COIDADE', 'AP_MVM', 'AP_CMP', 'AP_DTFIM', 'AP_MOTSAI', 'AP_TRANSF', 'AP_CATEND', 'AQ_TOTMPL', 'AQ_TOTMAU' ], axis=1, inplace=False)

# %%
import numpy as np

# Substituir os valores NaN por 0
df['AP_PRIPAL'] = df['AP_PRIPAL'].fillna(0)

# Convertendo a coluna para o formato MM/AAAA
df['AP_DTINIC'] = pd.to_datetime(df['AP_DTINIC'].astype(str), format='%Y%m%d').dt.strftime('%d/%m/%Y')


# Remover valores nulos (NaN, inf) diretamente sem conversão para int ou str
df['AQ_DTINI1'] = df['AQ_DTINI1'].replace([np.nan, np.inf, -np.inf], np.nan)
df['AQ_DTINI2'] = df['AQ_DTINI2'].replace([np.nan, np.inf, -np.inf], np.nan)
df['AQ_DTINI3'] = df['AQ_DTINI3'].replace([np.nan, np.inf, -np.inf], np.nan)
df['AQ_DTINTR'] = df['AQ_DTINTR'].replace([np.nan, np.inf, -np.inf], np.nan)
df['AP_PRIPAL'] = df['AP_PRIPAL'].replace([np.inf, -np.inf], 0)

# Converter a coluna para inteiro
df['AP_PRIPAL'] = df['AP_PRIPAL'].astype(int)

# Convertendo as colunas para o formato DD/MM/AAAA, lidando com valores nulos com errors='coerce'
df['AQ_DTINI1'] = pd.to_datetime(df['AQ_DTINI1'], format='%Y%m%d', errors='coerce').dt.strftime('%d/%m/%Y')
df['AQ_DTINI2'] = pd.to_datetime(df['AQ_DTINI2'], format='%Y%m%d', errors='coerce').dt.strftime('%d/%m/%Y')
df['AQ_DTINI3'] = pd.to_datetime(df['AQ_DTINI3'], format='%Y%m%d', errors='coerce').dt.strftime('%d/%m/%Y')
df['AQ_DTINTR'] = pd.to_datetime(df['AQ_DTINTR'], format='%Y%m%d', errors='coerce').dt.strftime('%d/%m/%Y')
# Exibindo o DataFrame
primeiros_linhas_b = df['AP_DTINIC'].head()
primeiros_linhas_g = df['AQ_DTINI1'].head()
primeiros_linhas_h = df['AQ_DTINI2'].head()
primeiros_linhas_i = df['AQ_DTINI3'].head()
primeiros_linhas_j = df['AQ_DTINTR'].head()



# Converter a coluna para inteiro
df['AP_PRIPAL'] = df['AP_PRIPAL'].astype(int)



print(primeiros_linhas_b)
print(primeiros_linhas_g)
print(primeiros_linhas_h)
print(primeiros_linhas_i)
print(primeiros_linhas_j)
# Out:
# 0    01/01/2008
# 1    01/01/2008
# 2    01/01/2008
# 3    01/01/2008
# 4    01/01/2008
# Name: AP_DTINIC, dtype: object
# 0    30/07/2007
# 1           NaN
# 2    17/11/2006
# 3           NaN
# 4    01/08/1999
# Name: AQ_DTINI1, dtype: object
# 0           NaN
# 1           NaN
# 2    20/03/2007
# 3           NaN
# 4           NaN
# Name: AQ_DTINI2, dtype: object
# 0           NaN
# 1           NaN
# 2    10/07/2007
# 3           NaN
# 4           NaN
# Name: AQ_DTINI3, dtype: object
# 0    18/10/2007
# 1    02/01/2008
# 2    01/10/2007
# 3    14/12/2007
# 4    20/05/2005
# Name: AQ_DTINTR, dtype: object

# %%
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# AP_CNSPCN        2922
# AQ_CID10      2575813
# AQ_LINFIN           1
# AQ_ESTADI      477099
# AQ_CIDINI1    2201850
# AQ_DTINI1     2199169
# AQ_CIDINI2    2916958
# AQ_DTINI2     2915351
# AQ_CIDINI3    3348416
# AQ_DTINI3     3347790
# AQ_CONTTR           1
# AQ_DTINTR          63
# AQ_ESQU_P1          1
# AQ_ESQU_P2    1067739
# dtype: int64

# %%
# Substituindo NaN por 0 nas colunas
df['AP_CNSPCN'] = df['AP_CNSPCN'].fillna('Não informado',  inplace=False)
df['AQ_CID10'] = df['AQ_CID10'].fillna('Desconhecido',  inplace=False)
df['AQ_LINFIN'] = df['AQ_LINFIN'].replace({'S': 1, 'N': 2, np.nan: 3},  inplace=False)
df['AQ_ESTADI'] = df['AQ_ESTADI'].fillna(5,  inplace=False)
df['AQ_CIDINI1'] = df['AQ_CIDINI1'].fillna('Desconhecido', inplace=False)
df['AQ_CIDINI2'] = df['AQ_CIDINI2'].fillna('Desconhecido', inplace=False)
df['AQ_CIDINI3'] = df['AQ_CIDINI3'].fillna('Desconhecido', inplace=False)
df['AQ_CONTTR'] = df['AQ_CONTTR'].fillna('N',  inplace=False)
df['AQ_DTINTR'] = df['AQ_DTINTR'].fillna(df['AP_DTINIC'],  inplace=False)
df['AQ_ESQU_P1'] = df['AQ_ESQU_P1'].fillna('Não informado',  inplace=False)

# Transformando a coluna para o tipo inteiro
df['AQ_ESTADI'] = df['AQ_ESTADI'].astype(int)

# Excluir linhas onde 'AP_CNSPCN' é nulo ou vazio
df = df[~df['AP_CNSPCN'].isin([None, 'Não informado'])]

# %%
# Filtrando e contando as linhas que têm o valor '{{{{{{{{{{{{{{' na coluna 'AP_CNSPCN'
count = df[df['AP_CNSPCN'] == '{{{{{{{{{{{{{{{'].shape[0]

print(count)

# Remover as linhas que têm o valor '{{{{{{{{{{{{{{' na coluna 'AP_CNSPCN'
df = df.drop(df[df['AP_CNSPCN'] == '{{{{{{{{{{{{{{{'].index)



count = df[df['AP_CNSPCN'] == '{{{{{{{{{{{{{{{'].shape[0]

print(count)
# Out:
# 1102
# 0

# %%
#Tratar os CID (retirar o último número)
df['AQ_CIDINI1'] = df['AQ_CIDINI1'].str.slice(0, -1)
df['AQ_CIDINI2'] = df['AQ_CIDINI2'].str.slice(0, -1)
df['AQ_CIDINI3'] = df['AQ_CIDINI3'].str.slice(0, -1)
df['AQ_CID10'] = df['AQ_CID10'].str.slice(0, -1)
df['AP_CIDPRI'] = df['AP_CIDPRI'].str.slice(0, -1)

# %%
# Certifique-se de que as colunas estão no formato datetime
df['AQ_DTINI1'] = pd.to_datetime(df['AQ_DTINI1'], errors='coerce')
df['AQ_DTINI2'] = pd.to_datetime(df['AQ_DTINI2'], errors='coerce')
df['AQ_DTINI3'] = pd.to_datetime(df['AQ_DTINI3'], errors='coerce')
df['AQ_DTINTR'] = pd.to_datetime(df['AQ_DTINTR'], errors='coerce')



# Calcular a diferença em dias entre AQ_DTINI1 e AQ_DTINI2
df['Tempo_Atual_1'] = (df['AQ_DTINI1'] - df['AQ_DTINTR']).dt.days

# Calcular a diferença em dias entre AQ_DTINI1 e AQ_DTINI2
df['Tempo_1_2'] = (df['AQ_DTINI2'] - df['AQ_DTINI1']).dt.days

# Calcular a diferença em dias entre AQ_DTINI2 e AQ_DTINI3, considerando 0 se AQ_DTINI3 for nulo
df['Tempo_2_3'] = (df['AQ_DTINI3'] - df['AQ_DTINI2']).dt.days

# Calcular a diferença em dias entre AQ_DTINI1 e AQ_DTINI3, considerando 0 se AQ_DTINI2, ou AQ_DTINI3 for nulo
df['Tempo_1_3'] = (df['AQ_DTINI3'] - df['AQ_DTINI1']).dt.days

# Substituir valores nulos na coluna 'Tempo_2_3' por 0
df['Tempo_2_3'].fillna(0, inplace=True)
df['Tempo_1_2'].fillna(0, inplace=True)
df['Tempo_1_3'].fillna(0, inplace=True)
df['Tempo_Atual_1'].fillna(0, inplace=True)
# Out:
# C:\Users\Rafaela\AppData\Local\Temp\ipykernel_20676\1932335515.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['AQ_DTINI1'] = pd.to_datetime(df['AQ_DTINI1'], errors='coerce')
# C:\Users\Rafaela\AppData\Local\Temp\ipykernel_20676\1932335515.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['AQ_DTINI2'] = pd.to_datetime(df['AQ_DTINI2'], errors='coerce')
# C:\Users\Rafaela\AppData\Local\Temp\ipykernel_20676\1932335515.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['AQ_DTINI3'] = pd.to_datetime(df['AQ_DTINI3'], errors='coerce')
# ...

# %%
df['Mudanca_de_Diagnostico_1'] = (df['AP_CIDPRI'] != df['AQ_CIDINI1']) & df['AP_CIDPRI'].notna().astype(int)
df['Mudanca_de_Diagnostico_2'] = (df['AQ_CIDINI2'] != df['AQ_CIDINI1']) & df['AQ_CIDINI2'].notna().astype(int)
df['Mudanca_de_Diagnostico_3'] = (df['AQ_CIDINI3'] != df['AQ_CIDINI2']) & df['AQ_CIDINI3'].notna().astype(int)

# %%
df['Numero_de_Tratamentos_Anteriores'] = df[['AQ_CIDINI1', 'AQ_CIDINI2', 'AQ_CIDINI3']].notna().sum(axis=1)

# %%
# Contar o número de diagnósticos diferentes ao longo dos tratamentos
df['Numero_de_Diagnosticos_Diferentes'] = df[['AQ_CIDINI1', 'AQ_CIDINI2', 'AQ_CIDINI3', 'AP_CIDPRI']].nunique(axis=1)

# %%
# Criar uma variável para indicar se há causas associadas ao tratamento
df['Tem_Causas_Associadas'] = df['AP_CIDCAS'].notna().astype(int)

# %%
df['esquema_terapeutico'] = df['AQ_ESQU_P1'].fillna('') + df['AQ_ESQU_P2'].fillna('') 
df['esquema_terapeutico'].value_counts()
# Out:
# TAMOXIFENO         442969
# ANASTROZOL         254212
# TMX                144555
# LECTRUM            127924
# TAMOX              114915
#                     ...
# DOCE+GENCIT             1
# CISPL+GENCITAB          1
# DOC+CDDP                1
# CISP+MAN+DOC+FU         1
# HERCEP+PERTU+ZO         1
# Name: esquema_terapeutico, Length: 36129, dtype: int64

# %%
# Contar a quantidade de valores únicos na coluna 'cns_paciente'
quantidade_unicos = df['AP_CNSPCN'].nunique()

#Quantidade de óbitos
df['AP_OBITO'].value_counts()

#Porcentagem de mortalidade
mortalidade = df['AP_OBITO'].value_counts()[1] / quantidade_unicos
mortalidade = mortalidade * 100


# Mostrar o resultado
print(quantidade_unicos)
print(mortalidade)
print(df['AP_OBITO'].value_counts())
# Out:
# 193308
# 5.651085314627434
# 0    3706704
# 1      10924
# Name: AP_OBITO, dtype: int64

# %%
# Supondo que df seja o seu DataFrame
df.drop(columns=['AP_CIDCAS', 'AQ_ESQU_P1', 'AQ_ESQU_P2' ], axis=1, inplace=False)
# Out:
#          AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR  \
# 0        304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4
# 1        304020052  âäâ{Ç{{üÇéüüââ~          64       F           2
# 2        304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4
# 3        304020176  âäâ{Ç{{ü~~}ä}          68       M           4
# 4        304020079  âäâ{Ç{{|{éâ{ä|          75       M           4
# ...            ...              ...         ...     ...         ...
# 3721647  304050342  é{â|{âÇ|â}âä~~          84       M           1
# 3721648  304050342  é{é{â{äâ||âé{          62       M           3
# 3721649  304050342  é{{{{|{â{â~|{}          72       M           2
# 3721650  304020087  âäâ{{}~üÇ~üüäÇÇ          72       M           3
# 3721651  304050342  âäâ{{âé~{{é{ää          80       M           2
#
#           AP_DTINIC  AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  ... Tempo_1_2  \
# 0        01/01/2008         0          0          1        0  ...       0.0
# ...

# %%
df['AP_CNSPCN'].head()
# df['AP_CNSPCN'].drop_duplicates().shape

pivot_table = pd.pivot_table(df, 
                             index=['AP_CNSPCN', 'AP_PRIPAL'], 
                             values=['AP_DTINIC', 'AQ_ESTADI'], 
                             aggfunc=['min', 'max'])
pivot_table.head()
# Out:
#                                   min                   max
#                             AP_DTINIC AQ_ESTADI   AP_DTINIC AQ_ESTADI
# AP_CNSPCN       AP_PRIPAL
# {}{~|ü~üé{{{~ 304020028  01/01/2008         3  01/12/2008         4
# |{{||äÇü~|{{{{Ç 304030074  19/06/2013         5  19/06/2013         5
#                 304030112  01/01/2014         5  27/07/2015         5
# |{{||üüÇ}|{{{Ç 304050121  01/03/2013         2  18/07/2017         2
# |{{|}é~ää{{{â 304020346  10/01/2013         3  29/10/2012         3

# %%
#Calcular a diferença do estadiamento entre os períodos

pivot_table['dif_estadiamento'] = pivot_table[('max','AQ_ESTADI')]-pivot_table[('min','AQ_ESTADI')]

#Contar a qauntidade de cada valor
pivot_table['dif_estadiamento'].value_counts()
# Out:
# 0    255326
# 1      9465
# 2      3809
# 4      1964
# 3      1665
# 5        69
# Name: dif_estadiamento, dtype: int64

# %%
pivot_table = pd.pivot_table(df, 
                             index=['AP_CNSPCN'], 
                             values=['AP_DTINIC', 'AQ_ESTADI'], 
                             aggfunc=['min', 'max'])

#Cálculo da Diferença entre o Máximo e Mínimo do Estadiamento
pivot_table['dif_estadiamento'] = pivot_table[('max','AQ_ESTADI')]-pivot_table[('min','AQ_ESTADI')]
pivot_table['dif_estadiamento'].value_counts()
# Out:
# 0    161708
# 1     18618
# 2      7431
# 3      2851
# 4      2430
# 5       270
# Name: dif_estadiamento, dtype: int64

# %%
# Renomear as colunas da tabela dinâmica
pivot_table = pivot_table.set_axis(['inicio','estadiamento_inicio','fim','estadiamento_fim','dif_estadiamento'], axis=1)
pivot_table.head()
# Out:
#                      inicio  estadiamento_inicio         fim  \
# AP_CNSPCN
# {}{~|ü~üé{{{~  01/01/2008                    3  01/12/2008
# |{{||äÇü~|{{{{Ç  01/01/2014                    5  27/07/2015
# |{{||üüÇ}|{{{Ç  01/03/2013                    2  18/07/2017
# |{{|}é~ää{{{â  10/01/2013                    3  29/10/2012
# |{{|Ç{ä~~{{{{ä  02/02/2013                    0  06/08/2012
#
#                  estadiamento_fim  dif_estadiamento
# AP_CNSPCN
# {}{~|ü~üé{{{~                 4                 1
# |{{||äÇü~|{{{{Ç                 5                 0
# |{{||üüÇ}|{{{Ç                 2                 0
# |{{|}é~ää{{{â                 5                 2
# |{{|Ç{ä~~{{{{ä                 4                 4

# %%
print(df.columns)
# Excluindo as colunas 'AQ_ESQU_P1' e 'AQ_ESQU_P2'
df.drop(columns=['AQ_ESQU_P1', 'AQ_ESQU_P2'], inplace=True)
df.drop(columns=['AP_CIDCAS', 'AQ_DTINTR', 'AQ_CONTTR' ], inplace=True)


print(df.columns)
# Out:
# Index(['AP_PRIPAL', 'AP_CNSPCN', 'AP_NUIDADE', 'AP_SEXO', 'AP_RACACOR',
#        'AP_DTINIC', 'AP_OBITO', 'AP_ENCERR', 'AP_PERMAN', 'AP_ALTA',
#        'AP_CIDCAS', 'AP_CIDPRI', 'AP_CIDSEC', 'AQ_CID10', 'AQ_LINFIN',
#        'AQ_ESTADI', 'AQ_TRANTE', 'AQ_CIDINI1', 'AQ_DTINI1', 'AQ_CIDINI2',
#        'AQ_DTINI2', 'AQ_CIDINI3', 'AQ_DTINI3', 'AQ_CONTTR', 'AQ_DTINTR',
#        'AQ_ESQU_P1', 'AQ_ESQU_P2', 'Tempo_Atual_1', 'Tempo_1_2', 'Tempo_2_3',
#        'Tempo_1_3', 'Mudanca_de_Diagnostico_1', 'Mudanca_de_Diagnostico_2',
#        'Mudanca_de_Diagnostico_3', 'Numero_de_Tratamentos_Anteriores',
#        'Numero_de_Diagnosticos_Diferentes', 'Tem_Causas_Associadas',
#        'esquema_terapeutico'],
#       dtype='object')
# Index(['AP_PRIPAL', 'AP_CNSPCN', 'AP_NUIDADE', 'AP_SEXO', 'AP_RACACOR',
#        'AP_DTINIC', 'AP_OBITO', 'AP_ENCERR', 'AP_PERMAN', 'AP_ALTA',
#        'AP_CIDPRI', 'AP_CIDSEC', 'AQ_CID10', 'AQ_LINFIN', 'AQ_ESTADI',
# ...

# %%
# Merge da tabela pivotada e do dataset
df = pd.merge(df, pivot_table, on=['AP_CNSPCN'], how='left')
df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4  304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#    AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  ... Mudanca_de_Diagnostico_3  \
# 0         0          0          1        0  ...                    False
# 1         0          0          1        0  ...                    False
# 2         0          0          1        0  ...                    False
# 3         0          0          1        0  ...                    False
# 4         0          0          1        0  ...                    False
#
#   Numero_de_Tratamentos_Anteriores Numero_de_Diagnosticos_Diferentes  \
# ...

# %%
# df.drop(columns=[('min', 'AP_DTINIC'), 
#                  ('min', 'AQ_ESTADI'), 
#                  ('max', 'AP_DTINIC'), 
#                  ('max', 'AQ_ESTADI'), 
#                  ('dif_estadiamento', '')], inplace=True)

# %%
# Pivotar tabela
pivot_table = pd.pivot_table(df, 
                             index=['AP_CNSPCN', 'AP_PRIPAL'], 
                             values=['AP_DTINIC', 'AQ_ESTADI'], 
                             aggfunc=['min', 'max'])

# Calcular o total de tratamento realizados pelo paciente
total_tratamentos = pivot_table.reset_index().groupby('AP_CNSPCN')['AP_PRIPAL'].count()

#Fazer o merge dessa coluna de total de tratamentos ao dataset.
df = pd.merge(df, total_tratamentos, on=['AP_CNSPCN'], how='left')
df.head()
# Out:
#    AP_PRIPAL_x        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0    304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1    304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2    304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3    304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4    304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#    AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  ...  \
# 0         0          0          1        0  ...
# 1         0          0          1        0  ...
# 2         0          0          1        0  ...
# 3         0          0          1        0  ...
# 4         0          0          1        0  ...
#
#   Numero_de_Tratamentos_Anteriores Numero_de_Diagnosticos_Diferentes  \
# 0                                3                                 2
# 1                                3                                 2
# ...

# %%
# Renomeando as colunas
df = df.rename(columns={'AP_PRIPAL_x': 'AP_PRIPAL'})
df = df.rename(columns={'AP_PRIPAL_y': 'total_tratamentos'})
df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4  304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#    AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  ...  \
# 0         0          0          1        0  ...
# 1         0          0          1        0  ...
# 2         0          0          1        0  ...
# 3         0          0          1        0  ...
# 4         0          0          1        0  ...
#
#   Numero_de_Tratamentos_Anteriores Numero_de_Diagnosticos_Diferentes  \
# 0                                3                                 2
# 1                                3                                 2
# ...

# %%
#Pivot da tabela
pivot_table = pd.pivot_table(df, 
                             index=['AP_CNSPCN', 'AP_PRIPAL'], 
                             values=['AP_DTINIC'], 
                             aggfunc=['min', 'max'])
procedimento_inicial = pivot_table.reset_index().groupby('AP_CNSPCN')['AP_PRIPAL'].first()

# Obtendo o Primeiro Procedimento por Paciente
df = pd.merge(df, procedimento_inicial, on=['AP_CNSPCN'], how='left')
df.head()
# Out:
#    AP_PRIPAL_x        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0    304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1    304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2    304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3    304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4    304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#    AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  ...  \
# 0         0          0          1        0  ...
# 1         0          0          1        0  ...
# 2         0          0          1        0  ...
# 3         0          0          1        0  ...
# 4         0          0          1        0  ...
#
#   Numero_de_Diagnosticos_Diferentes Tem_Causas_Associadas esquema_terapeutico  \
# 0                                 2                     1                 FAC
# ...

# %%
#Renomear colunas 
df = df.rename(columns={'AP_PRIPAL_x': 'AP_PRIPAL'})
df = df.rename(columns={'AP_PRIPAL_y': 'procedimento_inicial'})
df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4  304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#    AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  ...  \
# 0         0          0          1        0  ...
# 1         0          0          1        0  ...
# 2         0          0          1        0  ...
# 3         0          0          1        0  ...
# 4         0          0          1        0  ...
#
#   Numero_de_Diagnosticos_Diferentes Tem_Causas_Associadas esquema_terapeutico  \
# 0                                 2                     1                 FAC
# ...

# %%
# Criação da coluna Piora
df['piora'] = df['dif_estadiamento'].apply(lambda x: 1 if x > 0 else 0)
df['piora'].value_counts()

#Indicador de óbito 
df['obito'] = df['AP_OBITO'].apply(lambda x: 1 if x > 0 else 0)
df['obito'].value_counts()

#Indicador de Alta 
df['alta'] = df['AP_ALTA'].apply(lambda x: 1 if x > 0 else 0)
df['alta'].value_counts()

#Indicador de Melhora
df['melhora'] = df['AP_ENCERR'].apply(lambda x: 1 if x > 0 else 0)
df['melhora'].value_counts()
# Out:
# 0    3639216
# 1      78412
# Name: melhora, dtype: int64

# %%
#Pivot da tabela por CNS
pivot_table = pd.pivot_table(df,
                             index='AP_CNSPCN',
                             values=['obito','piora','melhora','alta'],
                             aggfunc='max'
                             )
pivot_table.head()
# Out:
#                  alta  melhora  obito  piora
# AP_CNSPCN
# {}{~|ü~üé{{{~     1        0      0      1
# |{{||äÇü~|{{{{Ç     1        0      0      0
# |{{||üüÇ}|{{{Ç     0        0      0      0
# |{{|}é~ää{{{â     0        0      0      1
# |{{|Ç{ä~~{{{{ä     0        0      0      1

# %%
# Verificar desfecho do Paciente
def verifica_desfecho(obito, piora, melhora, alta):
    if(obito > 0 ):
        return 'Óbito'
    elif(piora > 0 ):
        return 'Piora'
    elif(melhora > 0):
        return 'Melhora'
    elif(alta > 0):
        return 'Alta'
    else:
        return 'SemDesfecho'

#Criar coluna com esse desfecho
df['desfecho'] = np.vectorize(verifica_desfecho)(df['obito'], df['piora'], df['melhora'], df['alta'])
df['desfecho'].value_counts()
# Out:
# SemDesfecho    2513393
# Piora          1066688
# Alta             71721
# Melhora          54902
# Óbito            10924
# Name: desfecho, dtype: int64

# %%
# Excluindo as colunas 'AQ_ESQU_P1' e 'AQ_ESQU_P2'
df.drop(columns=['AP_OBITO', 'AP_ENCERR', 'AP_PERMAN', 'AP_ALTA'], inplace=True)

df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4  304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#   AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  ...         fim estadiamento_fim  \
# 0       C50      0000      C50         2  ...  02/04/2009                3
# 1       C25      0000      C25         1  ...  01/01/2008                4
# 2       C50      0000      C50         1  ...  02/09/2011                3
# 3       C15      0000      C15         2  ...  01/01/2008                4
# 4       C60      0000      C60         1  ...  01/08/2008                3
#
# ...

# %%
pivot_table['desfecho'] = np.vectorize(verifica_desfecho)(pivot_table['obito'], pivot_table['piora'], pivot_table['melhora'], pivot_table['alta'])
pivot_table['desfecho'].value_counts()
df = pd.merge(df, pivot_table, on='AP_CNSPCN', how='left')

# %%
# Renomear a coluna
df = df.rename(columns={'desfecho_y': 'desfecho'})
df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020052  âäâ{Ç{{üÇéüüââ~          64       F           2  01/01/2008
# 2  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 4  304020079  âäâ{Ç{{|{éâ{ä|          75       M           4  01/01/2008
#
#   AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  ...  piora_x obito_x alta_x  \
# 0       C50      0000      C50         2  ...        0       0      0
# 1       C25      0000      C25         1  ...        0       0      0
# 2       C50      0000      C50         1  ...        1       0      0
# 3       C15      0000      C15         2  ...        0       0      0
# 4       C60      0000      C60         1  ...        0       0      0
#
#   melhora_x   desfecho_x alta_y melhora_y obito_y  piora_y     desfecho
# ...

# %%
# Remover linhas sem desfecho
df = df.loc[df['desfecho'] != 'SemDesfecho',:]

# %%
# Excluindo as colunas 'AQ_ESQU_P1' e 'AQ_ESQU_P2'
df.drop(columns=['piora_x',	'obito_x',	'alta_x',	'melhora_x',	'desfecho_x',	'alta_y',	'melhora_y',	'obito_y',	'piora_y'], inplace=True)

df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 2  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 3  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 5  304020079  â{|~~{~Ç}|~üé          78       M           2  01/01/2008
# 6  304050083  }{~ü~é}â~äé{{{          38       F           3  01/01/2008
#
#   AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  ...  Tem_Causas_Associadas  \
# 0       C50      0000      C50         2  ...                      1
# 2       C50      0000      C50         1  ...                      1
# 3       C15      0000      C15         2  ...                      1
# 5        C6      0000       C6         3  ...                      1
# 6       C50      0000      C50         2  ...                      1
#
#   esquema_terapeutico      inicio estadiamento_inicio         fim  \
# ...

# %%
# Pivot da Tabela para pegar max e min da idade
pivot_table = pd.pivot_table(data=df,
                             index='AP_CNSPCN',
                             values=['AP_DTINIC', 'AP_NUIDADE'],
                             aggfunc=['min','max'])

#Renomeação das colunas
pivot_table = pivot_table.set_axis(['AP_DTINIC_min', 'idade_inicial', 'AP_DTINIC_max', 'idade_max'], axis=1)

#Merge com o dataset
df = pd.merge(df, pivot_table, on='AP_CNSPCN', how='left')
df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 2  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 3  304020079  â{|~~{~Ç}|~üé          78       M           2  01/01/2008
# 4  304050083  }{~ü~é}â~äé{{{          38       F           3  01/01/2008
#
#   AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  ...         fim estadiamento_fim  \
# 0       C50      0000      C50         2  ...  02/04/2009                3
# 1       C50      0000      C50         1  ...  02/09/2011                3
# 2       C15      0000      C15         2  ...  01/01/2008                4
# 3        C6      0000       C6         3  ...  01/04/2008                4
# 4       C50      0000      C50         2  ...  02/01/2014                4
#
#   dif_estadiamento total_tratamentos procedimento_inicial desfecho  \
# ...

# %%
# Excluindo as colunas 
df.drop(columns=['AP_DTINIC_min',	'AP_DTINIC_max'], inplace=True)

df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 2  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 3  304020079  â{|~~{~Ç}|~üé          78       M           2  01/01/2008
# 4  304050083  }{~ü~é}â~äé{{{          38       F           3  01/01/2008
#
#   AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  ...      inicio estadiamento_inicio  \
# 0       C50      0000      C50         2  ...  01/01/2008                   3
# 1       C50      0000      C50         1  ...  01/01/2008                   2
# 2       C15      0000      C15         2  ...  01/01/2008                   4
# 3        C6      0000       C6         3  ...  01/01/2008                   2
# 4       C50      0000      C50         2  ...  01/01/2008                   2
#
# ...

# %% [markdown]
# **One-Hot Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# Inicializar o LabelEncoder
le = LabelEncoder()

# Aplicar o LabelEncoder na coluna 'desfecho'
df['desfecho_encoded'] = le.fit_transform(df['desfecho'])
df['AP_PRIPAL_encoded'] = le.fit_transform(df['AP_PRIPAL'])

df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008
# 1  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008
# 2  304020176  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008
# 3  304020079  â{|~~{~Ç}|~üé          78       M           2  01/01/2008
# 4  304050083  }{~ü~é}â~äé{{{          38       F           3  01/01/2008
#
#   AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  ...         fim estadiamento_fim  \
# 0       C50      0000      C50         2  ...  02/04/2009                3
# 1       C50      0000      C50         1  ...  02/09/2011                3
# 2       C15      0000      C15         2  ...  01/01/2008                4
# 3        C6      0000       C6         3  ...  01/04/2008                4
# 4       C50      0000      C50         2  ...  02/01/2014                4
#
#   dif_estadiamento total_tratamentos procedimento_inicial desfecho  \
# ...

# %%
# Excluindo as colunas 'AQ_ESQU_P1' e 'AQ_ESQU_P2'
df.drop(columns=['AP_PRIPAL','desfecho'], inplace=True)

df.head()
# Out:
#          AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC AP_CIDPRI  \
# 0  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008       C50
# 1  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008       C50
# 2  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008       C15
# 3  â{|~~{~Ç}|~üé          78       M           2  01/01/2008        C6
# 4  }{~ü~é}â~äé{{{          38       F           3  01/01/2008       C50
#
#   AP_CIDSEC AQ_CID10 AQ_LINFIN  AQ_ESTADI  ... estadiamento_inicio  \
# 0      0000      C50         2          3  ...                   3
# 1      0000      C50         1          3  ...                   2
# 2      0000      C15         2          4  ...                   4
# 3      0000       C6         3          4  ...                   2
# 4      0000      C50         2          2  ...                   2
#
#           fim estadiamento_fim dif_estadiamento total_tratamentos  \
# ...

# %%
df['AP_CIDPRI_encoded'] = le.fit_transform(df['AP_CIDPRI'])
df['AQ_CID10_encoded'] = le.fit_transform(df['AQ_CID10'])
df['esquema_terapeutico'] = le.fit_transform(df['esquema_terapeutico'])


df.head()
# Out:
#          AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR   AP_DTINIC AP_CIDPRI  \
# 0  âäâ{Ç{{Çäââ}Ç~}          22       F           4  01/01/2008       C50
# 1  âäâ{Ç{{~âüÇâÇÇ          61       F           4  01/01/2008       C50
# 2  âäâ{Ç{{ü~~}ä}          68       M           4  01/01/2008       C15
# 3  â{|~~{~Ç}|~üé          78       M           2  01/01/2008        C6
# 4  }{~ü~é}â~äé{{{          38       F           3  01/01/2008       C50
#
#   AP_CIDSEC AQ_CID10 AQ_LINFIN  AQ_ESTADI  ... estadiamento_fim  \
# 0      0000      C50         2          3  ...                3
# 1      0000      C50         1          3  ...                3
# 2      0000      C15         2          4  ...                4
# 3      0000       C6         3          4  ...                4
# 4      0000      C50         2          2  ...                4
#
#   dif_estadiamento total_tratamentos procedimento_inicial idade_inicial  \
# ...

# %%
df.drop(columns=['AP_CIDPRI','AQ_CID10'], inplace=True)

# %%
# Codificando 'M' como 0 e 'F' como 1
df['AP_SEXO'] = df['AP_SEXO'].map({'M': 0, 'F': 1})

# Transformar coluna booleana 'booleano' de True/False para 1/0
df['Mudanca_de_Diagnostico_1'] = df['Mudanca_de_Diagnostico_1'].astype(int)
df['Mudanca_de_Diagnostico_2'] = df['Mudanca_de_Diagnostico_2'].astype(int)
df['Mudanca_de_Diagnostico_3'] = df['Mudanca_de_Diagnostico_3'].astype(int)

df['Mudanca_de_Diagnostico_1'].tail()

df.head()
# Out:
#          AP_CNSPCN  AP_NUIDADE  AP_SEXO  AP_RACACOR   AP_DTINIC AP_CIDSEC  \
# 0  âäâ{Ç{{Çäââ}Ç~}          22        1           4  01/01/2008      0000
# 1  âäâ{Ç{{~âüÇâÇÇ          61        1           4  01/01/2008      0000
# 2  âäâ{Ç{{ü~~}ä}          68        0           4  01/01/2008      0000
# 3  â{|~~{~Ç}|~üé          78        0           2  01/01/2008      0000
# 4  }{~ü~é}â~äé{{{          38        1           3  01/01/2008      0000
#
#   AQ_LINFIN  AQ_ESTADI AQ_TRANTE   AQ_CIDINI1  ... estadiamento_fim  \
# 0         2          3         0          C50  ...                3
# 1         1          3         0          C50  ...                3
# 2         2          4         0  Desconhecid  ...                4
# 3         3          4         0           C6  ...                4
# 4         2          2         N  Desconhecid  ...                4
#
#   dif_estadiamento total_tratamentos procedimento_inicial idade_inicial  \
# ...

# %%
df.drop(columns=['AQ_TRANTE', 'AQ_CIDINI1', 'AQ_DTINI1', 'AQ_CIDINI2', 'AQ_DTINI2', 'AQ_CIDINI3', 'AQ_DTINI3', 'AP_DTINIC'], inplace=True)
df.columns
# Out:
# Index(['AP_CNSPCN', 'AP_NUIDADE', 'AP_SEXO', 'AP_RACACOR', 'AP_CIDSEC',
#        'AQ_LINFIN', 'AQ_ESTADI', 'Tempo_Atual_1', 'Tempo_1_2', 'Tempo_2_3',
#        'Tempo_1_3', 'Mudanca_de_Diagnostico_1', 'Mudanca_de_Diagnostico_2',
#        'Mudanca_de_Diagnostico_3', 'Numero_de_Tratamentos_Anteriores',
#        'Numero_de_Diagnosticos_Diferentes', 'Tem_Causas_Associadas',
#        'esquema_terapeutico', 'inicio', 'estadiamento_inicio', 'fim',
#        'estadiamento_fim', 'dif_estadiamento', 'total_tratamentos',
#        'procedimento_inicial', 'idade_inicial', 'idade_max',
#        'desfecho_encoded', 'AP_PRIPAL_encoded', 'AP_CIDPRI_encoded',
#        'AQ_CID10_encoded'],
#       dtype='object')

# %% [markdown]
# **Normalização / Escalonamento**

# %%
from sklearn.preprocessing import MinMaxScaler

#Verificar se há valor na coluna 'AP_CIDSEC' e atribuir 0 ou 1
df['AP_CIDSEC_check'] = df['AP_CIDSEC'].apply(lambda x: 1 if pd.notnull(x) and x != '' else 0)


# Normalizar a idade para o intervalo [0, 1]
# scaler = MinMaxScaler()
# df['idade_normalizada'] = scaler.fit_transform(df[['AP_NUIDADE']])
# df['idade_inicial_normalizada'] = scaler.fit_transform(df[['idade_inicial']])
# df['idade_max_normalizada'] = scaler.fit_transform(df[['idade_max']])

print(df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[47], line 13
#       4 df['AP_CIDSEC_check'] = df['AP_CIDSEC'].apply(lambda x: 1 if pd.notnull(x) and x != '' else 0)
#       7 # Normalizar a idade para o intervalo [0, 1]
#       8 # scaler = MinMaxScaler()
#       9 # df['idade_normalizada'] = scaler.fit_transform(df[['AP_NUIDADE']])
#      10 # df['idade_inicial_normalizada'] = scaler.fit_transform(df[['idade_inicial']])
#      11 # df['idade_max_normalizada'] = scaler.fit_transform(df[['idade_max']])
# ---> 13 print(df)
#
# File c:\Users\Rafaela\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# ...

# %%
df.drop(columns=['AP_CIDSEC', 'AP_NUIDADE','idade_inicial', 'idade_max'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.drop(columns=['AP_CIDSEC', 'AP_NUIDADE','idade_inicial', 'idade_max'], inplace=True)
#
# File c:\Users\Rafaela\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Rafaela\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
from dateutil.relativedelta import relativedelta

# Convertendo as colunas para o tipo datetime
df['inicio'] = pd.to_datetime(df['inicio'])
df['fim'] = pd.to_datetime(df['fim'])
# Out:
# C:\Users\Rafaela\AppData\Local\Temp\ipykernel_19944\2295466836.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['inicio'] = pd.to_datetime(df['inicio'])
# C:\Users\Rafaela\AppData\Local\Temp\ipykernel_19944\2295466836.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['fim'] = pd.to_datetime(df['fim'])

# %%
# Função para calcular a diferença em meses
def calcular_diferenca_em_meses(row):
    inicio = row['inicio']
    fim = row['fim']
    delta = relativedelta(fim, inicio)
    # Calcula a diferença total em meses
    return delta.years * 12 + delta.months

# Aplicando a função para cada linha do DataFrame
df['diferenca_em_meses_incio_fim'] = df.apply(calcular_diferenca_em_meses, axis=1)

# Exibindo o resultado
print(df)

# %%
df.drop(columns=['incio','fim'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.drop(columns=['incio','fim'], inplace=True)
#
# NameError: name 'df' is not defined

# %%
#criando outro dataframe com campos específicos
df_analise = df[['AP_PRIPAL_encoded', 'AP_CNSPCN', 'Tempo_Atual_1', 'Tempo_1_2',
       'Tempo_2_3', 'Tempo_1_3', 'Mudanca_de_Diagnostico_1',
       'Mudanca_de_Diagnostico_2', 'Mudanca_de_Diagnostico_3',
       'Numero_de_Tratamentos_Anteriores', 'Numero_de_Diagnosticos_Diferentes',
       'Tem_Causas_Associadas', 'esquema_terapeutico',
       'estadiamento_inicio', 'estadiamento_fim', 'dif_estadiamento',
       'total_tratamentos', 'procedimento_inicial', 'desfecho_encoded',
       'idade_inicial_normalizada', 'idade_max_normalizada','diferenca_em_meses_incio_fim']]
df.head()
# Out:
#    AP_PRIPAL        AP_CNSPCN  AP_NUIDADE AP_SEXO  AP_RACACOR AP_CIDPRI  \
# 0  304050067  âäâ{Ç{{Çäââ}Ç~}          22       F           4       C50
# 1  304020141  âäâ{Ç{{~âüÇâÇÇ          61       F           4       C50
# 2  304020176  âäâ{Ç{{ü~~}ä}          68       M           4       C15
# 3  304020079  â{|~~{~Ç}|~üé          78       M           2        C6
# 4  304050083  }{~ü~é}â~äé{{{          38       F           3       C50
#
#   AP_CIDSEC AQ_CID10 AQ_LINFIN   AQ_CIDINI1  ...      inicio  \
# 0      0000      C50         2          C50  ...  01/01/2008
# 1      0000      C50         1          C50  ...  01/01/2008
# 2      0000      C15         2  Desconhecid  ...  01/01/2008
# 3      0000       C6         3           C6  ...  01/01/2008
# 4      0000      C50         2  Desconhecid  ...  01/01/2008
#
#   estadiamento_inicio         fim estadiamento_fim dif_estadiamento  \
# 0                   3  02/04/2009                3                0
# ...

# %% [markdown]
# **Redução de dimensionalidade (PCA)**

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

numerical_columns = [
    'AP_PRIPAL_encoded', 'AP_CNSPCN', 'Tempo_Atual_1', 'Tempo_1_2', 'Tempo_2_3', 
    'Tempo_1_3', 'Mudanca_de_Diagnostico_1', 'Mudanca_de_Diagnostico_2', 
    'Mudanca_de_Diagnostico_3', 'Numero_de_Tratamentos_Anteriores', 
    'Numero_de_Diagnosticos_Diferentes', 'Tem_Causas_Associadas', 'esquema_terapeutico', 
    'estadiamento_inicio', 'estadiamento_fim', 'dif_estadiamento', 'total_tratamentos', 
    'procedimento_inicial', 'desfecho_encoded', 'idade_inicial_normalizada', 
    'idade_max_normalizada', 'diferenca_em_meses_incio_fim'
]

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[numerical_columns])

pca = PCA(n_components=2)  # Vamos reduzir para 2 componentes principais
pca_components = pca.fit_transform(df_scaled)

# Visualizando a variância explicada pelos componentes principais
explained_variance = pca.explained_variance_ratio_
print(f"Variância explicada pelas componentes principais: {explained_variance}")

# %% [markdown]
# **Clusterização**

# %%
from sklearn.cluster import KMeans

# Definindo o número de clusters (vamos usar 3 clusters como exemplo)
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster_KMeans'] = kmeans.fit_predict(df[numerical_columns])

# Exibindo os resultados
print(df[['Paciente', 'Cluster_KMeans']])

# %%
from sklearn.cluster import DBSCAN

# Aplicando o DBSCAN (com parâmetros 'eps' e 'min_samples' ajustáveis)
dbscan = DBSCAN(eps=0.5, min_samples=2)
df['Cluster_DBSCAN'] = dbscan.fit_predict(df[numerical_columns])

# Exibindo os resultados
print(df[['Paciente', 'Cluster_DBSCAN']])

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# Aplicando o Agglomerative Clustering
hierarchical = AgglomerativeClustering(n_clusters=3)  # Definindo 3 clusters como exemplo
df['Cluster_Hierarchical'] = hierarchical.fit_predict(df[numerical_columns])

# Exibindo os resultados
print(df[['Paciente', 'Cluster_Hierarchical']])

# Criando o Dendrograma para visualização
plt.figure(figsize=(10, 7))
sch.dendrogram(sch.linkage(df[numerical_columns], method='ward'))
plt.title('Dendrograma - Clusterização Hierárquica')
plt.xlabel('Índice do Paciente')
plt.ylabel('Distância')
plt.show()

# %%
# Visualizando K-Means
plt.scatter(df['Tempo_Atual_1'], df['idade_inicial_normalizada'], c=df['Cluster_KMeans'], cmap='viridis')
plt.xlabel('Tempo Atual 1')
plt.ylabel('Idade Inicial Normalizada')
plt.title('Clusters K-Means')
plt.show()

# Visualizando DBSCAN
plt.scatter(df['Tempo_Atual_1'], df['idade_inicial_normalizada'], c=df['Cluster_DBSCAN'], cmap='plasma')
plt.xlabel('Tempo Atual 1')
plt.ylabel('Idade Inicial Normalizada')
plt.title('Clusters DBSCAN')
plt.show()

# Visualizando Hierarchical
plt.scatter(df['Tempo_Atual_1'], df['idade_inicial_normalizada'], c=df['Cluster_Hierarchical'], cmap='inferno')
plt.xlabel('Tempo Atual 1')
plt.ylabel('Idade Inicial Normalizada')
plt.title('Clusters Hierarchical')
plt.show()

# %% [markdown]
# **Análise de Sensibilidade**

# %%
# Calculando a Inertia (para o método do cotovelo)
inertia = []
sil_scores = []
for k in range(2, 11):  # Testando de 2 a 10 clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pca_components)
    inertia.append(kmeans.inertia_)
    
    # Calculando o Silhouette Score
    sil_score = silhouette_score(pca_components, kmeans.labels_)
    sil_scores.append(sil_score)

# Plotando a Curva do Elbow
plt.figure(figsize=(8, 6))
plt.plot(range(2, 11), inertia, marker='o', color='b')
plt.title('Curva do Elbow')
plt.xlabel('Número de Clusters')
plt.ylabel('Inertia')
plt.show()

# Plotando o Silhouette Score
plt.figure(figsize=(8, 6))
plt.plot(range(2, 11), sil_scores, marker='o', color='g')
plt.title('Silhouette Score para diferentes números de clusters')
plt.xlabel('Número de Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
# Lista das variáveis a serem alteradas
variables_to_modify = [
    'Tempo_Atual_1',
    'Numero_de_Tratamentos_Anteriores',
    'Numero_de_Diagnosticos_Diferentes',
    'dif_estadiamento',
    'Tem_Causas_Associadas',
    'total_tratamentos',
    'diferenca_em_meses_incio_fim',
    'idade_inicial_normalizada',
    'idade_max_normalizada'
]

# Criando uma cópia do DataFrame original para manipulação
df_copy = df.copy()

# Alterando as variáveis de forma simples: aumento ou diminuição de 2 unidades para variáveis contínuas
for var in variables_to_modify:
    if var in df_copy.columns:
        if df_copy[var].dtype in ['float64', 'int64']:  # Se a variável for numérica
            df_copy[var] = df_copy[var] + 2  # Aumenta em 2 para cada valor (exemplo)

# Normalizando os dados novamente
numerical_columns = df_copy[variables_to_modify].columns
scaler = StandardScaler()
df_copy_scaled = scaler.fit_transform(df_copy[numerical_columns])

# Aplicando PCA
pca = PCA(n_components=2)  # Reduzindo para 2 componentes principais para visualização
pca_components = pca.fit_transform(df_copy_scaled)

# Aplicando K-Means
kmeans = KMeans(n_clusters=3, random_state=42)  # Usando 3 clusters como exemplo
df_copy['Cluster_KMeans'] = kmeans.fit_predict(pca_components)

# Visualizando os clusters após a modificação
plt.figure(figsize=(8, 6))
plt.scatter(pca_components[:, 0], pca_components[:, 1], c=df_copy['Cluster_KMeans'], cmap='viridis')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.title('Clusterização após alteração das variáveis')
plt.colorbar(label='Cluster')
plt.show()

# Calculando o Silhouette Score para avaliar a qualidade da clusterização
silhouette_original = silhouette_score(pca_components, df_copy['Cluster_KMeans'])
print(f"Silhouette Score após alteração: {silhouette_original}")

# Comparando com a clusterização original
# Reaplicando KMeans nos dados originais (antes das alterações)
df_scaled = scaler.fit_transform(df[numerical_columns])
pca_components_original = pca.fit_transform(df_scaled)
kmeans_original = KMeans(n_clusters=3, random_state=42)
df['Cluster_KMeans'] = kmeans_original.fit_predict(pca_components_original)

# Calculando o Silhouette Score para o modelo original
silhouette_original_model = silhouette_score(pca_components_original, df['Cluster_KMeans'])
print(f"Silhouette Score original: {silhouette_original_model}")

# Exibindo a diferença nos Silhouette Scores
print(f"Diferença no Silhouette Score: {silhouette_original - silhouette_original_model}")

# %% [markdown]
# **Regressão Logística**

# %% [markdown]
# *Visualizaçaõ de Dados*

# %%
import seaborn as sns


# Histograma para a variável 'Tempo_Atual_1'
plt.figure(figsize=(10,6))
sns.histplot(df['Tempo_Atual_1'], kde=True, bins=20)
plt.title('Distribuição do Tempo Atual 1')
plt.xlabel('Tempo Atual 1')
plt.ylabel('Contagem')
plt.show()

# Histograma para a variável 'diferenca_em_meses_incio_fim'
plt.figure(figsize=(10,6))
sns.histplot(df['diferenca_em_meses_incio_fim'], kde=True, bins=20)
plt.title('Distribuição da Diferença em meses do ínico ao fim do tratamento')
plt.xlabel('Diferença em meses')
plt.ylabel('Contagem')
plt.show()

# Histograma para a variável 'Idade_max'
plt.figure(figsize=(10,6))
sns.histplot(df['idade_max_normalizada'], kde=True, bins=20)
plt.title('Distribuição da Idade Máxima atingida por Paciente')
plt.xlabel('Idade Máxima')
plt.ylabel('Contagem')
plt.show()


# Boxplot para 'Numero_de_Tratamentos_Anteriores'
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='desfecho_encoded', y='Numero_de_Tratamentos_Anteriores')
plt.title('Distribuição de Tratamentos Anteriores por Desfecho')
plt.xlabel('Desfecho')
plt.ylabel('Numero de Tratamentos Anteriores')
plt.show()


# Boxplot para 'Numero_de_Diagnosticos_Diferentes'
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='desfecho_encoded', y='Numero_de_Diagnosticos_Diferentes')
plt.title('Distribuição de Diagnósticos Diferentes por Desfecho')
plt.xlabel('Desfecho')
plt.ylabel('Numero de Diagnósticos Diferentes')
plt.show()


# Boxplot para 'total_tratamentos'
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='desfecho_encoded', y='total_tratamentos')
plt.title('Distribuição de Total de Tratamentos por Desfecho')
plt.xlabel('Desfecho')
plt.ylabel('Numero de Total de Tratamentos')
plt.show()

# Gráfico de dispersão entre 'Tem_Causas_Associadas' e 'desfecho_encoded'
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Tem_Causas_Associadas', y='desfecho_encoded', hue='desfecho_encoded', palette='viridis')
plt.title('Causas Associadas vs Desfecho')
plt.xlabel('Tem Causas Associadas')
plt.ylabel('Desfecho (0 ou 1)')
plt.show()

# %%
# Selecionar as variáveis para a análise
X = df[['estadiamento_inicio', 'dif_estadiamento']]  # Variáveis independentes
y = df['desfecho_encoded']  # Variável dependente (target)

# Padronizar os dados (PCA é sensível à escala)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA para reduzir para 2 componentes principais
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Criar um DataFrame com os resultados do PCA e a variável de desfecho
pca_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
pca_df['desfecho_encoded'] = y

# Plotar o gráfico de dispersão entre os 2 componentes principais
plt.figure(figsize=(10,6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='desfecho_encoded', palette='viridis', s=100, edgecolor='k')
plt.title('Análise Multivariada com PCA: Estadiamento Início, Diferença de Estadiamento e Desfecho')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.legend(title='Desfecho', loc='upper right')
plt.show()

# %% [markdown]
# *Matriz de Correlação*

# %%
# Matriz de correlação
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação entre Variáveis')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Separar variáveis independentes e dependente
X = df[['AP_PRIPAL_encoded', 'AP_CNSPCN', 'Tempo_Atual_1', 'Tempo_1_2', 'Tempo_2_3', 
        'Tempo_1_3', 'Mudanca_de_Diagnostico_1', 'Mudanca_de_Diagnostico_2', 
        'Mudanca_de_Diagnostico_3', 'Numero_de_Tratamentos_Anteriores', 
        'Numero_de_Diagnosticos_Diferentes', 'Tem_Causas_Associadas', 
        'esquema_terapeutico', 'estadiamento_inicio', 'estadiamento_fim', 
        'dif_estadiamento', 'total_tratamentos', 'procedimento_inicial', 
        'idade_inicial_normalizada', 'idade_max_normalizada', 'diferenca_em_meses_incio_fim']]
y = df['desfecho_encoded']  # Variável dependente

# Dividir o dataset em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Padronizar os dados
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# *Treinamento e Avaliação*

# %%
# Construir o modelo de regressão logística
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Previsões no conjunto de teste
y_pred = model.predict(X_test)

# Avaliar o modelo
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# %% [markdown]
# *Interpretação*

# %%
# Exibir os coeficientes do modelo
coefficients = pd.DataFrame({'Feature': X.columns, 'Coefficient': model.coef_[0]})
print(coefficients)

# Função para calcular AIC (AIC = 2k - 2ln(L), onde k é o número de parâmetros e L é a verossimilhança)
def calculate_aic(model, X, y):
    n = len(y)
    y_pred_proba = model.predict_proba(X)[:, 1]
    likelihood = np.sum(y * np.log(y_pred_proba) + (1 - y) * np.log(1 - y_pred_proba))
    k = X.shape[1]
    aic = 2 * k - 2 * likelihood
    return aic

# Calcular o AIC
aic_value = calculate_aic(model, X_test, y_test)
print(f"AIC do modelo: {aic_value}")

# %%
from sklearn.metrics import roc_curve, auc

# Fazer previsões de probabilidade no conjunto de teste
y_pred_proba = model.predict_proba(X_test)[:, 1]  # Pegando as probabilidades para a classe 1

# Calcular a curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calcular a AUC
roc_auc = auc(fpr, tpr)

# Plotar a curva ROC
plt.figure(figsize=(10,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)  # Linha diagonal
plt.xlabel('Taxa de Falsos Positivos (FPR)')
plt.ylabel('Taxa de Verdadeiros Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# Imprimir a AUC
print(f"AUC da Curva ROC: {roc_auc:.2f}")
