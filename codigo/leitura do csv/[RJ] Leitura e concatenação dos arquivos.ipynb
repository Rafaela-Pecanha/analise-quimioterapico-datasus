# %% [markdown]
# Ler arquivos

# %%
import pandas as pd
import pickle

# importar o arquivo csv RJ
tabela_quimioterapia_2008 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2008.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2009 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2009.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2010 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2010.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2011 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2011.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2012 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2012.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2013 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2013.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2014 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2014.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2015 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2015.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2016 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2016.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2017 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2017.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2018 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2018.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2019 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2019.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2020 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2020.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2021 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2021.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2022 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2022.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2023 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2023.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2024 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2024.csv', encoding='ISO-8859-1', low_memory=False)
tabela_quimioterapia_2024_1 = pd.read_csv('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/RJ/Quimioterapia_rj_2024_1.csv', encoding='ISO-8859-1', low_memory=False)

df=pd.concat([tabela_quimioterapia_2008, tabela_quimioterapia_2009, tabela_quimioterapia_2010,
    tabela_quimioterapia_2011, tabela_quimioterapia_2012, tabela_quimioterapia_2013,
    tabela_quimioterapia_2014, tabela_quimioterapia_2015, tabela_quimioterapia_2016,
    tabela_quimioterapia_2017, tabela_quimioterapia_2018, tabela_quimioterapia_2019,
    tabela_quimioterapia_2020, tabela_quimioterapia_2021, tabela_quimioterapia_2022,
    tabela_quimioterapia_2023, tabela_quimioterapia_2024, tabela_quimioterapia_2024_1])

# %%
#df.drop(['AP_APACANT'], axis=1, inplace=True)

dados_serializados = pickle.dumps(df)
with open('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/Pickle/arquivo_rj.pickle', 'wb') as arquivo:
    arquivo.write(dados_serializados)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.drop(['AP_APACANT'], axis=1, inplace=True)
#
# File c:\Users\Rafael\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
import re

# Função para identificar o formato e remover o último número
def remover_ultimo_numero(valor):
    # Verifica se o valor corresponde ao formato "letra + 3 números"
    if re.match(r'^[A-Za-z]\d{3}$', valor):
        # Retira o último número
        return valor[:-1]
    return valor


df['CID_PRIN_FORMATADO'] = df['AP_CIDPRI'].apply(remover_ultimo_numero)

# %%
# Cria um novo DataFrame filtrando as linhas onde a coluna 'CID_PRIN_FORMATADO' é 'C50'
df_c50 = df[df['CID_PRIN_FORMATADO'] == 'C50']

# Exibe o novo DataFrame
print(df_c50)
# Out:
#          AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  \
# 0        200801        EP     330000    2287358  3308200305290  200801
# 2        200801        EP     330000    2287358  3308200304299  200801
# 6        200801        MN     330220    2278855  3308200003450  200801
# 7        200801        MN     330220    2278855  3308200002371  200801
# 8        200801        MN     330330      12505  3308200263841  200801
# ...         ...       ...        ...        ...            ...     ...
# 3721532  202408        PG     330100    2287285  3324203782592  202408
# 3721533  202408        EP     330000    2269899  3324204709419  202408
# 3721534  202408        EP     330000    2292386  3324203692800  202408
# 3721535  202408        EP     330000    2292386  3324203702260  202408
# 3721547  202408        PG     330455    2269988  3324207269548  202407
#
#            AP_PRIPAL  AP_VL_AP  AP_UFMUN  AP_TPUPS  ...  AQ_MED02 AQ_MED03  \
# ...

# %%
dados_serializados = pickle.dumps(df_c50)
with open('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/Pickle/cancer_de_mama_regiao_sudeste.pickle', 'wb') as arquivo:
    arquivo.write(dados_serializados)

# %%
df = pd.read_pickle('C:/Users/Rafael/OneDrive/Documentos/TCC Rafaela/Dados/Pickle/cancer_de_mama_regiao_sudeste.pickle')
df.describe().transpose()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1938931 entries, 0 to 3721547
# Data columns (total 75 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   AP_MVM              int64
#  1   AP_CONDIC           object
#  2   AP_GESTAO           int64
#  3   AP_CODUNI           int64
#  4   AP_AUTORIZ          int64
#  5   AP_CMP              int64
#  6   AP_PRIPAL           float64
#  7   AP_VL_AP            float64
#  8   AP_UFMUN            int64
#  9   AP_TPUPS            int64
#  10  AP_TIPPRE           int64
#  11  AP_MN_IND           object
#  12  AP_CNPJCPF          int64
#  13  AP_CNPJMNT          float64
#  14  AP_CNSPCN           object
#  15  AP_COIDADE          int64
#  16  AP_NUIDADE          int64
#  17  AP_SEXO             object
#  18  AP_RACACOR          int64
#  19  AP_MUNPCN           int64
#  20  AP_UFNACIO          float64
#  21  AP_CEPPCN           int64
#  22  AP_UFDIF            int64
#  23  AP_MNDIF            int64
# ...
